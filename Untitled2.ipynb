# %% [markdown]
# <a href="https://colab.research.google.com/github/lacet-Maju/atividades-em-python/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Olá, mundo!")
# Out:
# Olá, mundo!

# %%
n1 = int(input("Digite um número: "))
n2 = int(input("Digite outro número: "))

print("Soma:", n1 + n2)
# Out:
# Digite um número: 1
# Digite outro número: 5
# Soma: 6

# %%
n1 = float(input("Nota 1: "))
n2 = float(input("Nota 2: "))
n3 = float(input("Nota 3: "))

media = (n1 + n2 + n3) / 3

print("Média:", media)
# Out:
# Nota 1: 1
# Nota 2: 3
# Nota 3: 8
# Média: 4.0

# %%
numero = int(input("Digite um número: "))

if numero % 2 == 0:
    print("Par")
else:
    print("Ímpar")

# %%
numero = int(input("Digite um número: "))

for i in range(1, 11):
    print(numero, "x", i, "=", numero * i)

# %%
idade = int(input("Digite sua idade: "))

if idade >= 18:
    print("Maior de idade")
else:
    print("Menor de idade")

# %%
for i in range(1, 11):
    print(i)

# %%
for i in range(10, 0, -1):
    print(i)

print("Fim!")

# %%
n1 = float(input("Número 1: "))
n2 = float(input("Número 2: "))

print("1 - Soma")
print("2 - Subtração")
print("3 - Multiplicação")
print("4 - Divisão")

opcao = input("Escolha: ")

if opcao == "1":
    print(n1 + n2)

elif opcao == "2":
    print(n1 - n2)

elif opcao == "3":
    print(n1 * n2)

elif opcao == "4":
    print(n1 / n2)

# %%
import random

numero = random.randint(1, 5)

palpite = int(input("Adivinhe o número: "))

if palpite == numero:
    print("Você acertou!")
else:
    print("Você errou!")
    print("O número era", numero)

# %%
lista = []

for i in range(3):
    item = input("Digite um item: ")
    lista.append(item)

print("Lista de compras:")
print(lista)
