# %% [markdown]
# <a href="https://colab.research.google.com/github/lacet-Maju/atividades-em-python/blob/main/medio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
notas = []

while True:
    nota = float(input("Digite uma nota (-1 para sair): "))

    if nota == -1:
        break

    notas.append(nota)

media = sum(notas) / len(notas)

print("Média:", media)

if media >= 7:
    print("Aprovado")

elif media >= 5:
    print("Recuperação")

else:
    print("Reprovado")
# Out:
# Digite uma nota (-1 para sair): 8
# Digite uma nota (-1 para sair): -1
# Média: 8.0
# Aprovado

# %%
saldo = 1000

while True:
    print("\n1 - Ver saldo")
    print("2 - Depositar")
    print("3 - Sacar")
    print("4 - Sair")

    opcao = input("Escolha: ")

    if opcao == "1":
        print("Saldo:", saldo)

    elif opcao == "2":
        valor = float(input("Valor depósito: "))
        saldo += valor
        print("Depósito realizado!")

    elif opcao == "3":
        valor = float(input("Valor saque: "))

        if valor <= saldo:
            saldo -= valor
            print("Saque realizado!")
        else:
            print("Saldo insuficiente")

    elif opcao == "4":
        break
# Out:
# 1 - Ver saldo
# 2 - Depositar
# 3 - Sacar
# 4 - Sair
# Escolha: 1
# Saldo: 1000
#
# 1 - Ver saldo
# 2 - Depositar
# 3 - Sacar
# 4 - Sair
# Escolha: 2
# Valor depósito: 4
# Depósito realizado!
#
# 1 - Ver saldo
# 2 - Depositar
# 3 - Sacar
# 4 - Sair
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_44575/50029570.py in <cell line: 0>()
#       7     print("4 - Sair")
#       8
# ----> 9     opcao = input("Escolha: ")
#      10
#      11     if opcao == "1":
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...

# %%
import random

opcoes = ["pedra", "papel", "tesoura"]

computador = random.choice(opcoes)

usuario = input("Escolha pedra, papel ou tesoura: ").lower()

print("Computador escolheu:", computador)

if usuario == computador:
    print("Empate")

elif (
    (usuario == "pedra" and computador == "tesoura") or
    (usuario == "papel" and computador == "pedra") or
    (usuario == "tesoura" and computador == "papel")
):
    print("Você venceu!")

else:
    print("Você perdeu!")
# Out:
# Escolha pedra, papel ou tesoura: papel
# Computador escolheu: papel
# Empate

# %%
import random
import string

tamanho = int(input("Tamanho da senha: "))

caracteres = string.ascii_letters + string.digits

senha = ""

for i in range(tamanho):
    senha += random.choice(caracteres)

print("Senha gerada:", senha)
# Out:
# Tamanho da senha: 6
# Senha gerada: epUFHp

# %%
pontos = 0

print("Qual a capital do Brasil?")
resposta = input("Resposta: ").lower()

if resposta == "brasília":
    pontos += 1

print("Quanto é 5 + 5?")
resposta = input("Resposta: ")

if resposta == "10":
    pontos += 1

print("Python é uma linguagem de programação?")
resposta = input("Resposta: ").lower()

if resposta == "sim":
    pontos += 1

print("Pontuação final:", pontos)
# Out:
# Qual a capital do Brasil?
# Resposta: brasilia
# Quanto é 5 + 5?
# Resposta: 10
# Python é uma linguagem de programação?
# Resposta: sim
# Pontuação final: 2

# %%
tarefas = []

while True:
    print("\n1 - Adicionar")
    print("2 - Ver tarefas")
    print("3 - Remover")
    print("4 - Sair")

    opcao = input("Escolha: ")

    if opcao == "1":
        tarefa = input("Digite a tarefa: ")
        tarefas.append(tarefa)

    elif opcao == "2":
        for i, tarefa in enumerate(tarefas):
            print(i, "-", tarefa)

    elif opcao == "3":
        numero = int(input("Número da tarefa: "))
        tarefas.pop(numero)

    elif opcao == "4":
        break
# Out:
# 1 - Adicionar
# 2 - Ver tarefas
# 3 - Remover
# 4 - Sair
# Escolha: 1
# Digite a tarefa: matematica
#
# 1 - Adicionar
# 2 - Ver tarefas
# 3 - Remover
# 4 - Sair
# Escolha: 2
# 0 - matematica
#
# 1 - Adicionar
# 2 - Ver tarefas
# 3 - Remover
# 4 - Sair
# Escolha: 4

# %%
alunos = []

while True:
    nome = input("Nome do aluno:")

    if nome == "":
        break

    idade = input("Idade: ")
    curso = input("Curso: ")

    aluno = {
        "nome": nome,
        "idade": idade,
        "curso": curso
    }

    alunos.append(aluno)

print("\nAlunos cadastrados:")

for aluno in alunos:
    print(aluno)
# Out:
# Nome do aluno:julia
# Idade: 20
# Curso: ads

# %%
import random

numero = random.randint(1, 100)

tentativas = 0

while True:
    palpite = int(input("Digite um número: "))
    tentativas += 1

    if palpite == numero:
        print("Acertou!")
        print("Tentativas:", tentativas)
        break

    elif palpite < numero:
        print("O número é maior")

    else:
        print("O número é menor")
